# %%
from sklearn import datasets

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
diabetes = datasets.load_diabetes()

# %%
type(diabetes)
# Out:
# sklearn.utils.Bunch

# %%
dir(diabetes)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# diabetes

# %%
diabetes.data[:10]
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, -0.02632783, -0.00844872,
#         -0.01916334,  0.07441156, -0.03949338, -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, -0.00567061, -0.04559945,
#         -0.03419447, -0.03235593, -0.00259226,  0.00286377, -0.02593034],
#        [-0.08906294, -0.04464164, -0.01159501, -0.03665645,  0.01219057,
#          0.02499059, -0.03603757,  0.03430886,  0.02269202, -0.00936191],
#        [ 0.00538306, -0.04464164, -0.03638469,  0.02187235,  0.00393485,
#          0.01559614,  0.00814208, -0.00259226, -0.03199144, -0.04664087],
#        [-0.09269548, -0.04464164, -0.04069594, -0.01944209, -0.06899065,
#         -0.07928784,  0.04127682, -0.0763945 , -0.04118039, -0.09634616],
#        [-0.04547248,  0.05068012, -0.04716281, -0.01599922, -0.04009564,
# ...

# %%
diabetes.target[:10]
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310.])

# %%
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size = 0.3, random_state=123456)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [   0.88344869 -228.95940929  586.51882755  291.48268133 -720.87460703
#   395.52012225  226.25389411  374.92192841  650.93489885   12.95543774]

# %%
print(model.intercept_)
# Out:
# 150.23235471555608

# %%
# to evaluate the model

# %%
print(model.score(X_test, y_test))
# Out:
# 0.5167044027981857

# %%
y_pred = model.predict(X_test)

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.5167044027981857

# %%
# %matplotlib inline

# %%
# For those who cannot plot the subplot right
# try to put 'plt.figure(figsize=(20,15))' and for loop in one line

# %%
plt.figure(figsize=(20,15))
for i in range(10):
    xi_train = X_train[:,i]
    xi_train = xi_train[:,np.newaxis]
    linreg = LinearRegression()
    linreg.fit(xi_train,y_train)
    r2_i = linreg.score(xi_train,y_train)
    y_pred = linreg.predict(xi_train)
    plt.subplot(3,4,i+1)
    plt.scatter(xi_train,y_train,color='k')
    plt.plot(xi_train,y_pred,color='b',linewidth=3)
    plt.xlabel(diabetes.feature_names[i])
    plt.ylabel('Target')
    plt.title('%s%f'%('r2 = ',r2_i))
    plt.savefig('Diabetes.jpg')
plt.show()
